# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Fabian S.**
#
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because I want to be able to automate my work_

# %% [markdown]
# ### I will print "Machine Learning"

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %% [markdown]
# ---
#
# * bullet one
# * bullet two
#
#
# 1. number one
# 2. number two
#
# This is [Google](https://www.google.com)
#
# ![alt text](https://cdn.vox-cdn.com/thumbor/Pkmq1nm3skO0-j693JTMd7RL0Zk=/0x0:2012x1341/1200x800/filters:focal(0x0:2012x1341)/cdn.vox-cdn.com/uploads/chorus_image/image/47070706/google2.0.0.jpg "Google Logo")
#
#
# > This is Blockquote
#
#
# ~~Strikethrough~~
